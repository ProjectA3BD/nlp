# %% [markdown]
# # Sentiment Analysis
# ----

# %% [markdown]
# ## Data Load

# %%
import pandas as pd

df_corpus = pd.read_pickle('corpus/economics.corpus')
df_corpus.sample(5)
# Out:
#        AvgTone    EventID  sentiment  \
# 1072 -4.802744  541325728         -1
# 410  -4.056646  716388127         -1
# 199  -9.215442  751176352         -1
# 493  -8.894879  705890676         -1
# 446  -0.060382  709267406          0
#
#                                                    text  \
# 1072  Singapore's non-oil domestic exports (NODX) co...
# 410   By Agustinus Beo Da Costa\n\nJAKARTA, Dec 19 (...
# 199   Setya Novanto's case sparked a mix of rage and...
# 493   JAKARTA (Reuters) - Indonesia's speaker of par...
# 446   By Cindy Silviana\n\nJAKARTA (Reuters) - Indon...
#
#                                                     url
# 1072  1911    http://www.businesstimes.com.sg:80/ene...
# 410   1240    http://markets.businessinsider.com/new...
# 199   402    http://www.businesstimes.com.sg/governm...
# 493   1298    http://www.businessinsider.com/r-indon...
# 446   1275    http://www.businessinsider.com/r-arres...

# %%
df_corpus.shape
# Out:
# (1207, 5)

# %% [markdown]
# ## Data Preparation

# %%
from sklearn.cross_validation import train_test_split

X = df_corpus.text
y = df_corpus.sentiment

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from nltk.stem.porter import PorterStemmer
import re

porter_stemmer = PorterStemmer()

def stemming_tokenizer(str_input):
    words = re.sub(r"[^a-z]", " ", str_input).lower().split()
#     words = [porter_stemmer.stem(word) for word in words]
    return words

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 

# token_pattern='[a-z]+',
# tokenizer=stemming_tokenizer,
vectorizer = TfidfVectorizer(analyzer=u'word', tokenizer=stemming_tokenizer, stop_words='english',min_df=0.05, max_df=0.8, lowercase=True)
X = vectorizer.fit_transform(X_train)

X_train_dtm = vectorizer.transform(X_train)

# %%
pd.DataFrame(X_train_dtm.toarray(), columns=vectorizer.get_feature_names())
# Out:
#           able    access  according   account   accused   achieve       act  \
# 0     0.000000  0.000000   0.044435  0.000000  0.000000  0.000000  0.000000
# 1     0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# 3     0.000000  0.033714   0.000000  0.000000  0.000000  0.000000  0.000000
# 4     0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# 5     0.000000  0.000000   0.030358  0.000000  0.000000  0.000000  0.000000
# 6     0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# 7     0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# 8     0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# 9     0.000000  0.000000   0.000000  0.091211  0.000000  0.000000  0.000000
# 10    0.000000  0.123564   0.000000  0.000000  0.000000  0.000000  0.000000
# 11    0.000000  0.000000   0.000000  0.000000  0.077740  0.000000  0.000000
# 12    0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# 13    0.000000  0.000000   0.085657  0.000000  0.078985  0.000000  0.000000
# 14    0.000000  0.000000   0.037381  0.000000  0.000000  0.000000  0.000000
# 15    0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# 16    0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.139354
# 17    0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# 18    0.000000  0.000000   0.120002  0.000000  0.000000  0.000000  0.000000
# 19    0.000000  0.000000   0.068088  0.000000  0.000000  0.000000  0.000000
# 20    0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# 21    0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# 22    0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# 23    0.000000  0.000000   0.013503  0.069454  0.000000  0.000000  0.000000
# 24    0.000000  0.000000   0.035490  0.000000  0.000000  0.000000  0.061468
# 25    0.000000  0.043683   0.000000  0.000000  0.000000  0.000000  0.049254
# 26    0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
#
0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1057  0.000000  0.000000  0.000000  0.000000  0.066596  0.000000  0.000000
# 1058  0.000000  0.000000  0.000000  0.000000  0.000000  0.026625  0.000000
# 1059  0.000000  0.000000  0.000000  0.000000  0.122253  0.099380  0.000000
# 1060  0.000000  0.000000  0.000000  0.000000  0.049301  0.000000  0.000000
# 1061  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1062  0.000000  0.000000  0.000000  0.031513  0.013860  0.016900  0.000000
# 1063  0.000000  0.000000  0.000000  0.000000  0.028310  0.000000  0.000000
# 1064  0.000000  0.000000  0.000000  0.000000  0.015918  0.000000  0.000000
# 1065  0.000000  0.055020  0.000000  0.000000  0.070850  0.000000  0.117147
# 1066  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.119819
# 1067  0.000000  0.000000  0.000000  0.000000  0.177607  0.000000  0.000000
# 1068  0.056703  0.000000  0.000000  0.000000  0.083946  0.014623  0.000000
# 1069  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1070  0.000000  0.000000  0.000000  0.000000  0.000000  0.017489  0.000000
# 1071  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.094446
# 1072  0.000000  0.000000  0.000000  0.000000  0.053417  0.000000  0.000000
# 1073  0.033331  0.000000  0.000000  0.000000  0.056394  0.034382  0.000000
# 1074  0.000000  0.000000  0.000000  0.000000  0.048505  0.000000  0.000000
# 1075  0.000000  0.000000  0.000000  0.000000  0.022702  0.055363  0.000000
# 1076  0.066052  0.000000  0.000000  0.000000  0.000000  0.034068  0.000000
# 1077  0.000000  0.000000  0.000000  0.000000  0.069727  0.000000  0.000000
# 1078  0.103716  0.000000  0.000000  0.000000  0.043870  0.000000  0.000000
# 1079  0.029923  0.000000  0.000000  0.000000  0.012657  0.030867  0.031392
# 1080  0.000000  0.000000  0.000000  0.102134  0.000000  0.000000  0.000000
# 1081  0.000000  0.000000  0.000000  0.000000  0.070384  0.064368  0.000000
# 1082  0.000000  0.051905  0.000000  0.000000  0.044559  0.027167  0.000000
# 1083  0.000000  0.000000  0.000000  0.000000  0.021219  0.000000  0.000000
# 1084  0.000000  0.064222  0.062259  0.000000  0.027566  0.000000  0.000000
# 1085  0.000000  0.000000  0.000000  0.088102  0.000000  0.000000  0.000000
#
# [1086 rows x 894 columns]

# %% [markdown]
# # K-Means Clustering
# ----

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

true_k = 15
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X_train_dtm)

print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()

    
for i in range(true_k):
    
    t = []
    for ind in order_centroids[i, :20]:
        t.append(terms[ind])
    
    print("Cluster %d:" % i, ','.join(t),'\n')
# Out:
# Top terms per cluster:
# Cluster 0: factory,police,tangerang,fireworks,workers,bodies,jakarta,hospital,told,people,explosion,metro,injured,warehouse,kosambi,explosions,away,scene,reuters,yuwono
#
# Cluster 1: biodiesel,argentina,imports,u,department,commerce,antidumping,duties,producers,preliminary,duty,determination,trade,countervailing,market,percent,final,board,government,nbb
#
# Cluster 2: factory,people,police,victims,tangerang,told,blaze,fireworks,injured,tv,killed,metro,explosions,jakarta,explosion,afp,building,complex,bodies,dozens
#
# Cluster 3: freeport,oil,year,billion,million,percent,rm,fields,saudi,copper,company,palm,quarter,cent,bhd,china,eni,adkerson,sales,group
#
# Cluster 4: factory,police,bus,workers,safety,fireworks,people,hospital,killed,jakarta,explosion,fitriyah,work,incident,tangerang,women,told,owner,thursday,friday
#
# Cluster 5: percent,tax,tobacco,trade,china,trillion,year,economic,growth,exports,minister,meikarta,oil,rp,government,countries,country,palm,development,fintech
#
# Cluster 6: migrant,workers,law,state,antam,indonesian,regulation,treaty,budget,saleh,imwa,marsudi,government,jakarta,taxis,issue,provincial,retno,rights,bahrun
#
# Cluster 7: triangle,golden,species,wildlife,trade,asia,china,bali,illegal,ivory,intra,fishing,cookie,myanmar,laos,tourism,tourists,world,elephant,travel
#
# Cluster 8: gas,lng,infrastructure,energy,demand,coal,salt,production,project,deficit,supply,development,ag,asia,million,p,sewerage,waitsia,oil,projects
#
# Cluster 9: asean,whatsapp,flight,apec,feature,indian,countries,services,gif,company,says,air,million,region,market,summit,business,finders,com,tenor
#
# Cluster 10: police,ega,factory,welding,hartanto,liyono,sparks,fireworks,equipment,jakarta,suspects,saturday,afinta,owner,named,workers,negligence,indra,operational,subarna
#
# Cluster 11: papua,birds,paradise,fsc,bird,krui,forests,forest,plantations,sorong,malagufuk,damar,palm,binur,village,species,farmers,oil,illegal,traditional
#
# Cluster 12: president,nigeria,jokowi,vice,osinbajo,cooperation,eiti,countries,economic,meeting,indonesian,wedding,kalla,government,transparency,minister,jakarta,widodo,ownership,business
#
# Cluster 13: airport,police,tonnes,million,marawi,company,asia,maute,business,year,group,njop,reuters,yarn,deal,fertiliser,pundi,browser,sirius,baco
#
# Cluster 14: kkr,indosari,energy,power,company,renewable,electricity,investment,corpindo,nippon,coal,roti,bitcoin,qatar,indonesian,leading,market,products,solar,sector

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

centroids = model.cluster_centers_

tsne_init = 'pca'  # could also be 'random'
tsne_perplexity = 20.0
tsne_early_exaggeration = 4.0
tsne_learning_rate = 1000
random_state = 1
model = TSNE(n_components=2, random_state=random_state, init=tsne_init, perplexity=tsne_perplexity,
         early_exaggeration=tsne_early_exaggeration, learning_rate=tsne_learning_rate)

transformed_centroids = model.fit_transform(centroids)
print(transformed_centroids)
plt.scatter(transformed_centroids[:, 0], transformed_centroids[:, 1], marker='x')
plt.show()
# Out:
# [[-1330.2863  -2525.626  ]
#  [-3297.69      705.28467]
#  [-2531.1138  -1118.7448 ]
#  [ 1673.3164   2845.8206 ]
#  [   56.71113  1033.4347 ]
#  [ 1665.5703    929.1104 ]
#  [ -573.51044  -822.24725]
#  [ 3362.8433   1597.2188 ]
#  [ -152.117    2853.6792 ]
#  [  484.62912 -2792.2817 ]
#  [ 2206.7092  -2088.6755 ]
#  [ 1031.6235   -685.7249 ]
#  [-1507.2632    635.02997]
#  [ 3073.1619   -430.94608]
#  [-1963.7454   2470.6646 ]]
